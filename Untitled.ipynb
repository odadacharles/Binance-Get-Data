# %%
import pandas as pd

# %%
pd.options.display.max_rows=400
kline_data_df = pd.read_pickle('daily_20_kline_df')
kline_data_df
# Out:
#   Trading_Pair   Opening Time   Opening Price   Closing Price  \
# 0       ETHBTC  1638363600000      0.08170000      0.08112300
# 0       ETHBTC  1638367200000      0.08112400      0.08099100
# 0       ETHBTC  1638370800000      0.08099500      0.08061500
# 0       ETHBTC  1638374400000      0.08061600      0.08037300
# 0       ETHBTC  1638378000000      0.08038300      0.08059800
# 0       ETHBTC  1638381600000      0.08060600      0.08090300
# 0       ETHBTC  1638385200000      0.08090200      0.08115100
# 0       ETHBTC  1638388800000      0.08114500      0.08043000
# 0       ETHBTC  1638392400000      0.08041900      0.08012700
# 0       ETHBTC  1638396000000      0.08012700      0.07997900
# 0       ETHBTC  1638399600000      0.07997700      0.08015100
# 0       ETHBTC  1638403200000      0.08014600      0.08030300
# 0       ETHBTC  1638406800000      0.08030300      0.08061000
# 0       ETHBTC  1638410400000      0.08061700      0.08035900
# ...
